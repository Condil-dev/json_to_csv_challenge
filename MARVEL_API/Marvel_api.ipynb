# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
num = 0
my_list = []
new_list = []
while num < 1600:
  params = {"apikey":" ", "ts":1665756612,
            "hash":" ","orderBy":"name",
            "limit":100,
            "offset":f'{num}' }
  endpoint = "https://gateway.marvel.com:443/v1/public/characters"
  response = requests.get(endpoint, params=params)
  response_json = response.json()
  character_id = str(response_json["data"]["results"][0]["id"])
  if response_json["code"] == 200:
    len_ = len(response_json["data"]["results"])
    params = {"apikey":" ", "ts":1665756612,
            "hash":" "}
    endpoint = 'https://gateway.marvel.com:443/v1/public/characters/' + character_id
    response_1 = requests.get(endpoint, params=params)
    response_json_1 = response_1.json()
    if response_json_1["code"] == 200:
      id = response_json_1["data"]["results"][0]["id"]
      if int(character_id) == id:
        for i in range(len_):
          character_id = response_json["data"]["results"][i]["id"]
          character_name = response_json["data"]["results"][i]["name"]
          character_descr = response_json["data"]["results"][i]["description"]
          character_comics_no = response_json["data"]["results"][i]["comics"]["available"]
          character_series_no = response_json["data"]["results"][i]["series"]["available"]
          character_stories_no = response_json["data"]["results"][i]["stories"]["available"]
          character_events_no = response_json["data"]["results"][i]["events"]["available"]
          my_list.append(character_id)
          my_list.append(character_name)
          my_list.append(character_descr)
          my_list.append(character_comics_no)
          my_list.append(character_series_no)
          my_list.append(character_stories_no)
          my_list.append(character_events_no)
          my_tuple = tuple(my_list)
          new_list.append(my_tuple)
          my_list = []
        num+=100
        print(f'length of new_list is currently {len(new_list)}')
      else:
          print(f'{character_id} and {id} are not the same')
    else:
      print(response_1.status_code)
      print(response_json_1["code"])
      print(response_json_1["message"])      
  else:
    print(response.status_code)
    print(response_json["code"])
    print(response_json["message"])

new_list
# Out:
# length of new_list is currently 100
# length of new_list is currently 200
# length of new_list is currently 300
# length of new_list is currently 400
# length of new_list is currently 500
# length of new_list is currently 600
# length of new_list is currently 700
# length of new_list is currently 800
# length of new_list is currently 900
# length of new_list is currently 1000
# length of new_list is currently 1100
# length of new_list is currently 1200
# length of new_list is currently 1300
# length of new_list is currently 1400
# length of new_list is currently 1500
# length of new_list is currently 1562
# [(1011334, '3-D Man', '', 12, 3, 21, 1),
#  (1017100,
#   'A-Bomb (HAS)',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_records(new_list, columns = ['id', 'name', 'description', 'comics', 'series', 'stories', 'events'] )

# %%
df
# Out:
#            id                        name  \
# 0     1011334                     3-D Man
# 1     1017100                A-Bomb (HAS)
# 2     1009144                      A.I.M.
# 3     1010699                 Aaron Stack
# 4     1009146  Abomination (Emil Blonsky)
# ...       ...                         ...
# 1557  1011515                        Zeus
# 1558  1011127                      Zodiak
# 1559  1009741        Zombie (Simon Garth)
# 1560  1011183                       Zuras
# 1561  1009742                       Zzzax
#
#                                             description  comics  series  \
# 0                                                            12       3
# 1     Rick Jones has been Hulk's best bud since day ...       4       2
# 2     AIM is a terrorist organization bent on destro...      51      34
# 3                                                            14       3
# 4     Formerly known as Emil Blonsky, a spy of Sovie...      55      27
# ...

# %%
len(df['id'].unique())
# Out:
# 1562

# %%
df.to_csv('marvel_superheroes.csv')
from google.colab import files
files.download('marvel_superheroes.csv')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !cp marvel_superheroes.csv "/content/drive/My Drive/de_project/"
